# %%
import time
import yfinance as yf
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from datetime import datetime
import requests
import logging
import os
from dotenv import load_dotenv

# --- Load environment variables ---
load_dotenv()

API_KEY = os.getenv("API_KEY")
DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")
DB_PORT = os.getenv("DB_PORT")

logging.basicConfig(filename='trading.log', level=logging.INFO, format='%(asctime)s:%(levelname)s:%(message)s')

# Use psycopg2 as the database driver to avoid asyncpg dependency issue
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# API Keys
ALPHA_VANTAGE_API_KEY = {API_KEY}
ALPHA_VANTAGE_URL = "https://www.alphavantage.co/query"

# %%
def clean_stock_data(df):
    # Initial log of raw data shape
    logging.info(f'Initial data shape: {df.shape}')

    # Basic checks
    initial_rows = df.shape[0]

    # Remove rows with non-positive prices or volume
    df = df[(df['close_price'] > 0) & (df['volume'] > 0)]
    logging.info(f'Removed {initial_rows - df.shape[0]} rows with non-positive price or volume.')

    # Check for missing values and log them
    missing_before = df.isnull().sum().sum()
    if missing_before > 0:
        logging.info(f'Missing values before imputation: {missing_before}')

    # Impute missing values for prices and volumes using forward fill, then backward fill
    df['close_price'] = df['close_price'].ffill().bfill()
    df['volume'] = df['volume'].ffill().bfill()

    # Check if any missing values remain
    missing_after = df.isnull().sum().sum()
    if missing_after == 0:
        logging.info('All missing values handled.')
    else:
        logging.warning(f'Remaining missing values after imputation: {missing_after}')

    # Final log of cleaned data shape
    logging.info(f'Final data shape after cleaning: {df.shape}')

    return df

# %%
#Validate DataFrame before calculations
def validate_dataframe(df):
    if df is None or df.empty:
        raise ValueError("Input DataFrame is empty or None.")
    if "close_price" not in df.columns:
        raise ValueError("Input DataFrame must contain 'close_price' column.")
    
def aggregate_data(df):
    validate_dataframe(df)
    logging.info("Aggregating data by date to prevent duplication.")
    aggregated_df = df.groupby('date').agg({
        'close_price': 'mean',
        'rsi': 'mean',
        'macd': 'mean',
        'macd_signal': 'mean'
    }).reset_index()
    logging.info(f"Aggregation completed. Resulting shape: {aggregated_df.shape}")
    return aggregated_df

# Function to calculate moving averages
def calculate_moving_averages(df, short_window=10, long_window=50):
    validate_dataframe(df)
    logging.info("Calculating moving averages with short_window=%d and long_window=%d", short_window, long_window)
    df[f"moving_avg_{short_window}"] = df["close_price"].rolling(window=short_window, min_periods=short_window).mean()
    df[f"moving_avg_{long_window}"] = df["close_price"].rolling(window=long_window, min_periods=long_window).mean()
    logging.info("Moving averages calculation completed")
    return df

# Function to calculate RSI
def calculate_rsi(df, period=14):
    validate_dataframe(df)
    logging.info("Calculating RSI with period %d", period)
    delta = df["close_price"].diff()

    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)

    avg_gain = gain.rolling(window=period, min_periods=period).mean()
    avg_loss = loss.rolling(window=period, min_periods=period).mean()

    rs = avg_gain / avg_loss.replace(0, 1)
    rsi = 100 - (100 / (1 + rs))

    df["rsi"] = rsi.clip(0, 100)
    logging.info("RSI calculation completed")
    return df

# Function to calculate MACD
def calculate_macd(df, short_period=12, long_period=26, signal_period=9):
    validate_dataframe(df)
    logging.info("Calculating MACD with short_period=%d, long_period=%d, signal_period=%d", short_period, long_period, signal_period)
    df["macd"] = df["close_price"].ewm(span=short_period, adjust=False).mean() - \
                 df["close_price"].ewm(span=long_period, adjust=False).mean()
    df["macd_signal"] = df["macd"].ewm(span=signal_period, adjust=False).mean()
    logging.info("MACD calculation completed")
    return df

# Function to apply all trend analysis
def apply_trend_analysis(df):
    validate_dataframe(df)
    logging.info("Applying trend analysis")
    df = calculate_moving_averages(df)
    df = calculate_rsi(df)
    df = calculate_macd(df)
    logging.info("Trend analysis completed")
    return df

# %%
# Predefined list of stock symbols
stock_symbols = ["AAPL", "MSFT", "AMZN", "GOOGL", "NVDA"]

def insert_dim_stock(symbol):
    with engine.begin() as conn:
        result = conn.execute(text("SELECT stock_id FROM dim_stocks WHERE symbol = :symbol"), {"symbol": symbol}).fetchone()
        if result is None:
            conn.execute(text("INSERT INTO dim_stocks (symbol, company_name) VALUES (:symbol, :company_name)"),
                         {"symbol": symbol, "company_name": symbol})
            print(f"Inserted {symbol} into dim_stocks.")
        return conn.execute(text("SELECT stock_id FROM dim_stocks WHERE symbol = :symbol"), {"symbol": symbol}).scalar()

def insert_dim_date(date):
    date_str = date.strftime('%Y-%m-%d')
    with engine.begin() as conn:
        result = conn.execute(text("SELECT date_id FROM dim_dates WHERE full_date = :date"), {"date": date_str}).fetchone()
        if result is None:
            conn.execute(text("""
                INSERT INTO dim_dates (full_date, year, quarter, month, day, day_of_week, hour, am_pm)
                VALUES (:full_date, :year, :quarter, :month, :day, :day_of_week, :hour, :am_pm)
            """), {
                "full_date": date_str, "year": date.year, "quarter": (date.month - 1) // 3 + 1,
                "month": date.month, "day": date.day, "day_of_week": date.strftime('%A'),
                "hour": 0, "am_pm": "AM"
            })
        return conn.execute(text("SELECT date_id FROM dim_dates WHERE full_date = :date"), {"date": date_str}).scalar()

def insert_fact_trade(stock_id, date_id, trade_type, quantity, trade_price, volume):
    if trade_price <= 0 or volume <= 0:
        print(f'⚠ Skipping trade insertion due to invalid data: trade_price={trade_price}, volume={volume}')
        return
    
    with engine.begin() as conn:
        existing_trade = conn.execute(text("""
            SELECT 1 FROM fact_trades 
            WHERE stock_id = :stock_id AND date_id = :date_id AND trade_type = :trade_type 
            AND quantity = :quantity AND trade_price = :trade_price AND volume = :volume
        """), {
            "stock_id": stock_id, "date_id": date_id, "trade_type": trade_type,
            "quantity": quantity, "trade_price": trade_price, "volume": volume
        }).fetchone()
        
        if existing_trade:
            print(f'⚠ Skipping duplicate trade for stock_id={stock_id}, date_id={date_id}')
            return
        
        conn.execute(text("""
            INSERT INTO fact_trades (stock_id, date_id, trade_type, quantity, trade_price, volume)
            VALUES (:stock_id, :date_id, :trade_type, :quantity, :trade_price, :volume)
        """), {
            "stock_id": stock_id, "date_id": date_id, "trade_type": trade_type,
            "quantity": quantity, "trade_price": trade_price, "volume": volume
        })

def insert_fact_trends(stock_id, date_id, moving_avg_10, moving_avg_50, rsi, macd, macd_signal, price_change):
    with engine.begin() as conn:
        existing_trend = conn.execute(text("""
            SELECT 1 FROM fact_trends 
            WHERE stock_id = :stock_id AND date_id = :date_id
        """), {
            "stock_id": stock_id,
            "date_id": date_id
        }).fetchone()

        if existing_trend:
            print(f'⚠ Skipping duplicate trend data for stock_id={stock_id}, date_id={date_id}')
            return

        conn.execute(text("""
            INSERT INTO fact_trends (stock_id, date_id, moving_avg_10, moving_avg_50, rsi, macd, macd_signal, price_change)
            VALUES (:stock_id, :date_id, :moving_avg_10, :moving_avg_50, :rsi, :macd, :macd_signal, :price_change)
        """), {
            "stock_id": stock_id, "date_id": date_id,
            "moving_avg_10": moving_avg_10, "moving_avg_50": moving_avg_50,
            "rsi": rsi, "macd": macd, "macd_signal": macd_signal,
            "price_change": price_change
        })


def fetch_from_alpha_vantage(symbol):
    try:
        params = {
            "function": "TIME_SERIES_DAILY_ADJUSTED",
            "symbol": symbol,
            "apikey": ALPHA_VANTAGE_API_KEY,
            "outputsize": "full",
            "datatype": "json"
        }
        response = requests.get(ALPHA_VANTAGE_URL, params=params)
        data = response.json()
        
        if "Time Series (Daily)" not in data:
            print(f"⚠ Alpha Vantage data unavailable for {symbol}.")
            return None
        
        df = pd.DataFrame.from_dict(data["Time Series (Daily)"], orient="index")
        df.reset_index(inplace=True)
        df.rename(columns={
            "index": "Date",
            "1. open": "open_price",
            "4. close": "close_price",
            "2. high": "high",
            "3. low": "low",
            "6. volume": "volume"
        }, inplace=True)
        df["Date"] = pd.to_datetime(df["Date"])
        df.sort_values("Date", ascending=True, inplace=True)
        print(f"Alpha Vantage data fetched for {symbol}")
        return df
    except Exception as e:
        print(f"Alpha Vantage error for {symbol}: {e}")
        return None

def fetch_stock_data(stock_symbols, start="2024-01-01", end="2025-01-01"):
    all_stocks_data = {}
    for symbol in stock_symbols:
        try:
            stock = yf.download(symbol, start=start, end=end)
            if stock is None or stock.empty:
                print(f"⚠ No data from Yahoo Finance for {symbol}, trying Alpha Vantage...")
                stock = fetch_from_alpha_vantage(symbol)
                if stock is None or stock.empty:
                    print(f"No data available for {symbol}, skipping...")
                    continue
            
            print(f"Successfully fetched data for {symbol}: ")
            stock.rename(columns={"Open": "open_price", "Close": "close_price", "High": "high", "Low": "low", "Volume": "volume"}, inplace=True)
            stock = clean_stock_data(stock)
            stock["symbol"] = symbol
            stock.reset_index(inplace=True)

            # Apply calculations before trend analysis
            stock["daily_change"] = stock["close_price"].diff()

            # Apply trend analysis
            stock = apply_trend_analysis(stock)

            stock_id = insert_dim_stock(symbol)
            for _, row in stock.iterrows():
                if any(pd.isnull([row['open_price'], row['volume']])) or row['open_price'].item() <= 0 or row['volume'].item() <= 0:
                    print(f'⚠ Skipping invalid row for {symbol}: {row}')
                    continue
                date_value = row['Date'].iloc[0].date() if isinstance(row['Date'], pd.Series) else pd.to_datetime(row['Date']).date()
                date_id = insert_dim_date(date_value)
                trade_price = float(row['open_price'])
                volume = int(row['volume'])
                moving_avg_10 = float(row["moving_avg_10"].iloc[0]) if isinstance(row["moving_avg_10"], pd.Series) else float(row["moving_avg_10"])
                moving_avg_50 = float(row["moving_avg_50"].iloc[0]) if isinstance(row["moving_avg_50"], pd.Series) else float(row["moving_avg_50"])
                rsi = float(row["rsi"].iloc[0]) if isinstance(row["rsi"], pd.Series) else float(row["rsi"])
                macd = float(row["macd"].iloc[0]) if isinstance(row["macd"], pd.Series) else float(row["macd"])
                macd_signal = float(row["macd_signal"].iloc[0]) if isinstance(row["macd_signal"], pd.Series) else float(row["macd_signal"])
                price_change = float(row["daily_change"].iloc[0]) if isinstance(row["daily_change"], pd.Series) else float(row["daily_change"])

                insert_fact_trade(stock_id, date_id, 'BUY', 100, trade_price, volume)
                insert_fact_trends(stock_id, date_id, moving_avg_10, moving_avg_50, rsi, macd, macd_signal, price_change)


            all_stocks_data[symbol] = stock
            print(f"Data successfully loaded into PostgreSQL for {symbol}!")

        except Exception as e:
            print(f"Error fetching or inserting data for {symbol}: {e}")

    return all_stocks_data

def fetch_real_time_data(symbol, retry_attempts=3, retry_delay=5):
    stock = yf.Ticker(symbol)
    for attempt in range(retry_attempts):
        try:
            data = stock.history(period="1d")
            if not data.empty:
                break
        except Exception as e:
            print(f"⚠ Attempt {attempt + 1} failed for {symbol}: {e}")
            time.sleep(retry_delay)
    else:
        print(f"All {retry_attempts} attempts failed for {symbol}")
        return fetch_from_alpha_vantage(symbol)
    
    if data.empty:
        print(f"⚠ No real-time data from Yahoo Finance for {symbol}, trying Alpha Vantage...")
        return fetch_from_alpha_vantage(symbol)
    
    data.reset_index(inplace=True)
    data.rename(columns={"Open": "open_price", "Close": "close_price", "High": "high", "Low": "low", "Volume": "volume"}, inplace=True)
    print(f"Real-time data fetched for {symbol} from Yahoo Finance")
    return data

def update_real_time_data(stock_symbols, interval=60, duration=None):
    start_time = time.time()
    while duration is None or (time.time() - start_time) < duration:
        for symbol in stock_symbols:
            data = fetch_real_time_data(symbol)
            if data is not None and not data.empty:
                stock_id = insert_dim_stock(symbol)
                for _, row in data.iterrows():
                    if pd.isnull(row['open_price']) or pd.isnull(row['volume']) or row['open_price'] <= 0 or row['volume'] <= 0:
                        print(f'⚠ Skipping invalid row for {symbol}: {row}')
                        continue
                    date_value = pd.to_datetime(row['Date']).iloc[0].date() if isinstance(row['Date'], pd.Series) else pd.to_datetime(row['Date']).date()
                    date_id = insert_dim_date(date_value)
                    trade_price = float(row['open_price'])
                    volume = int(row['volume'])
                    insert_fact_trade(stock_id, date_id, 'BUY', 100, trade_price, volume)
                print(f"Real-time data updated for {symbol} in PostgreSQL")
        
        try:
            time.sleep(interval)
        except KeyboardInterrupt:
            print("⏹ Real-time data update stopped by user.")
            break

def fetch_trend_data(symbol):
    query = f"""
    SELECT d.full_date AS date, t.moving_avg_10, t.moving_avg_50, t.rsi, t.macd, t.macd_signal, 
           f.trade_price AS close_price, f.volume
    FROM fact_trends t
    JOIN dim_stocks s ON t.stock_id = s.stock_id
    JOIN dim_dates d ON t.date_id = d.date_id  -- JOIN to get full_date
    JOIN fact_trades f ON t.stock_id = f.stock_id AND t.date_id = f.date_id
    WHERE s.symbol = '{symbol}'
    ORDER BY d.full_date;
    """
    df = pd.read_sql(query, engine)

    # Rename & Convert Date Column
    df["date"] = pd.to_datetime(df["date"])  

    return df

# %%
all_stock_data = fetch_stock_data(stock_symbols)


# Print the first few rows of data for each stock
for symbol, df in all_stock_data.items():
    print(f"\n📊 Stock Data for {symbol}:")
    print(df[["Date", "close_price", "moving_avg_10", "daily_change"]].tail(50))

# Start real-time data update
update_real_time_data(stock_symbols, duration=3)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:147: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   trade_price = float(row['open_price'])
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:148: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   volume = int(row['volume'])
# Successfully fetched data for AAPL:
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=256
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=257
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=258
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=259
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=260
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=261
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=262
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=263
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=264
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=265
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=266
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=267
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=268
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=269
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=270
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=271
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=272
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=273
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=274
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=275
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=276
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=277
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=278
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=279
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=280
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=281
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=282
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=283
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=284
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=285
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=286
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=287
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=288
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=289
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=290
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=291
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=292
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=293
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=294
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=295
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=296
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=297
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=298
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=299
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=300
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=301
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=302
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=303
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=304
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=305
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=306
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=307
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=308
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=309
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=310
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=311
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=312
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=313
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=314
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=315
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=316
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=317
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=318
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=319
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=320
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=321
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=322
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=323
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=324
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=325
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=326
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=327
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=328
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=329
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=330
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=331
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=332
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=333
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=334
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=335
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=336
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=337
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=338
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=339
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=340
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=341
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=342
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=343
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=344
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=345
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=346
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=347
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=348
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=349
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=350
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=351
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=352
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=353
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=354
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=355
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=356
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=357
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=358
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=359
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=360
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=361
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=362
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=363
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=364
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=365
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=366
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=367
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=368
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=369
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=370
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=371
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=372
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=373
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=374
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=375
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=376
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=377
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=378
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=379
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=380
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=381
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=382
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=383
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=384
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=385
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=386
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=387
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=388
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=389
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=390
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=391
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=392
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=393
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=394
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=395
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=396
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=397
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=398
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=399
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=400
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=401
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=402
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=403
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=404
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=405
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=406
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=407
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=408
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=409
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=410
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=411
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=412
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=413
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=414
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=415
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=416
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=417
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=418
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=419
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=420
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=421
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=422
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=423
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=424
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=425
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=426
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=427
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=428
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=429
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=430
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=431
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=432
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=433
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=434
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=435
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=436
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=437
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=438
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=439
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=440
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=441
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=442
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=443
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=444
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=445
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=446
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=447
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=448
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=449
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=450
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=451
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=452
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=453
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=454
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=455
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=456
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=457
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=458
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=459
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=460
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=461
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=462
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=463
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=464
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=465
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=466
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=467
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=468
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=469
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=470
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=471
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=472
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=473
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=474
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=475
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=476
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=477
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=478
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=479
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=480
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=481
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=482
# [*********************100%***********************]  1 of 1 completed
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=483
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=484
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=485
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=486
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=487
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=488
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=489
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=490
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=491
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=492
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=493
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=494
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=495
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=496
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=497
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=498
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=499
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=500
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=501
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=502
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=503
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=504
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=505
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=506
# ⚠ Skipping duplicate trend data for stock_id=6, date_id=507
# Data successfully loaded into PostgreSQL for AAPL!
# Successfully fetched data for MSFT:
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:147: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   trade_price = float(row['open_price'])
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:148: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   volume = int(row['volume'])
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=256
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=257
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=258
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=259
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=260
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=261
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=262
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=263
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=264
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=265
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=266
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=267
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=268
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=269
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=270
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=271
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=272
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=273
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=274
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=275
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=276
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=277
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=278
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=279
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=280
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=281
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=282
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=283
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=284
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=285
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=286
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=287
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=288
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=289
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=290
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=291
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=292
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=293
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=294
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=295
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=296
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=297
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=298
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=299
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=300
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=301
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=302
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=303
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=304
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=305
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=306
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=307
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=308
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=309
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=310
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=311
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=312
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=313
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=314
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=315
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=316
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=317
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=318
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=319
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=320
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=321
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=322
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=323
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=324
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=325
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=326
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=327
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=328
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=329
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=330
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=331
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=332
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=333
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=334
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=335
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=336
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=337
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=338
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=339
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=340
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=341
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=342
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=343
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=344
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=345
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=346
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=347
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=348
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=349
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=350
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=351
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=352
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=353
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=354
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=355
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=356
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=357
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=358
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=359
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=360
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=361
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=362
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=363
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=364
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=365
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=366
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=367
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=368
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=369
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=370
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=371
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=372
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=373
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=374
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=375
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=376
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=377
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=378
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=379
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=380
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=381
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=382
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=383
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=384
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=385
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=386
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=387
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=388
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=389
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=390
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=391
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=392
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=393
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=394
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=395
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=396
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=397
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=398
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=399
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=400
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=401
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=402
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=403
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=404
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=405
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=406
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=407
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=408
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=409
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=410
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=411
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=412
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=413
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=414
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=415
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=416
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=417
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=418
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=419
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=420
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=421
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=422
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=423
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=424
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=425
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=426
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=427
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=428
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=429
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=430
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=431
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=432
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=433
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=434
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=435
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=436
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=437
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=438
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=439
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=440
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=441
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=442
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=443
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=444
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=445
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=446
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=447
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=448
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=449
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=450
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=451
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=452
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=453
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=454
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=455
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=456
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=457
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=458
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=459
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=460
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=461
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=462
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=463
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=464
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=465
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=466
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=467
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=468
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=469
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=470
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=471
# [*********************100%***********************]  1 of 1 completed
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=472
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=473
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=474
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=475
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=476
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=477
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=478
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=479
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=480
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=481
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=482
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=483
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=484
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=485
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=486
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=487
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=488
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=489
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=490
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=491
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=492
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=493
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=494
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=495
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=496
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=497
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=498
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=499
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=500
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=501
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=502
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=503
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=504
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=505
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=506
# ⚠ Skipping duplicate trend data for stock_id=7, date_id=507
# Data successfully loaded into PostgreSQL for MSFT!
# Successfully fetched data for AMZN:
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=256
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=257
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=258
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=259
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=260
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=261
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=262
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=263
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=264
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=265
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=266
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=267
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:147: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   trade_price = float(row['open_price'])
# /var/folders/_s/bwb12c8x3cnd5rpxh6xx0hl40000gn/T/ipykernel_21348/300356212.py:148: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   volume = int(row['volume'])
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=268
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=269
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=270
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=271
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=272
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=273
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=274
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=275
# ⚠ Skipping duplicate trade for stock_id=8, date_id=276
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=276
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=277
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=278
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=279
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=280
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=281
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=282
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=283
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=284
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=285
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=286
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=287
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=288
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=289
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=290
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=291
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=292
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=293
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=294
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=295
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=296
# ⚠ Skipping duplicate trade for stock_id=8, date_id=297
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=297
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=298
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=299
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=300
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=301
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=302
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=303
# ⚠ Skipping duplicate trade for stock_id=8, date_id=304
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=304
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=305
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=306
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=307
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=308
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=309
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=310
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=311
# ⚠ Skipping duplicate trade for stock_id=8, date_id=312
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=312
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=313
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=314
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=315
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=316
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=317
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=318
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=319
# ⚠ Skipping duplicate trade for stock_id=8, date_id=320
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=320
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=321
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=322
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=323
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=324
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=325
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=326
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=327
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=328
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=329
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=330
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=331
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=332
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=333
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=334
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=335
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=336
# ⚠ Skipping duplicate trade for stock_id=8, date_id=337
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=337
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=338
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=339
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=340
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=341
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=342
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=343
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=344
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=345
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=346
# ⚠ Skipping duplicate trade for stock_id=8, date_id=347
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=347
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=348
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=349
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=350
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=351
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=352
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=353
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=354
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=355
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=356
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=357
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=358
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=359
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=360
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=361
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=362
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=363
# ⚠ Skipping duplicate trade for stock_id=8, date_id=364
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=364
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=365
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=366
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=367
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=368
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=369
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=370
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=371
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=372
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=373
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=374
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=375
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=376
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=377
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=378
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=379
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=380
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=381
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=382
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=383
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=384
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=385
# ⚠ Skipping duplicate trade for stock_id=8, date_id=386
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=386
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=387
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=388
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=389
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=390
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=391
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=392
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=393
# ⚠ Skipping duplicate trade for stock_id=8, date_id=394
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=394
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=395
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=396
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=397
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=398
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=399
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=400
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=401
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=402
# ⚠ Skipping duplicate trade for stock_id=8, date_id=403
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=403
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=404
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=405
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=406
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=407
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=408
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=409
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=410
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=411
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=412
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=413
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=414
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=415
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=416
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=417
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=418
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=419
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=420
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=421
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=422
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=423
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=424
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=425
# ⚠ Skipping duplicate trade for stock_id=8, date_id=426
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=426
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=427
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=428
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=429
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=430
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=431
# ⚠ Skipping duplicate trade for stock_id=8, date_id=432
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=432
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=433
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=434
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=435
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=436
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=437
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=438
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=439
# ⚠ Skipping duplicate trade for stock_id=8, date_id=440
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=440
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=441
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=442
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=443
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=444
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=445
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=446
# ⚠ Skipping duplicate trade for stock_id=8, date_id=447
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=447
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=448
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=449
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=450
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=451
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=452
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=453
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=454
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=455
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=456
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=457
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=458
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=459
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=460
# ⚠ Skipping duplicate trade for stock_id=8, date_id=461
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=461
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=462
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=463
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=464
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=465
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=466
# ⚠ Skipping duplicate trade for stock_id=8, date_id=467
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=467
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=468
# [*********************100%***********************]  1 of 1 completed
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=469
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=470
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=471
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=472
# ⚠ Skipping duplicate trade for stock_id=8, date_id=473
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=473
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=474
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=475
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=476
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=477
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=478
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=479
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=480
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=481
# ⚠ Skipping duplicate trade for stock_id=8, date_id=482
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=482
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=483
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=484
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=485
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=486
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=487
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=488
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=489
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=490
# ⚠ Skipping duplicate trade for stock_id=8, date_id=491
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=491
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=492
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=493
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=494
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=495
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=496
# ⚠ Skipping duplicate trend data for stock_id=8, date_id=497
# ...
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=500
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=501
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=502
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=503
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=504
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=505
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=506
# ⚠ Skipping duplicate trend data for stock_id=10, date_id=507
# Data successfully loaded into PostgreSQL for NVDA!
#
# 📊 Stock Data for AAPL:
# Price        Date close_price moving_avg_10 daily_change
# Ticker                   AAPL
# 202    2024-10-21  235.960678    230.738171     1.476761
# 203    2024-10-22  235.342041    231.744955    -0.618637
# 204    2024-10-23  230.253235    231.866687    -5.088806
# 205    2024-10-24  230.063675    232.019353    -0.189560
# 206    2024-10-25  230.901810    232.404504     0.838135
# 207    2024-10-28  232.887436    232.614043     1.985626
# 208    2024-10-29  233.156845    232.596082     0.269409
# 209    2024-10-30  229.594681    232.428450    -3.562164
# 210    2024-10-31  225.413895    231.805821    -4.180786
# 211    2024-11-01  222.420471    230.599477    -2.993423
# 212    2024-11-04  221.522446    229.155653    -0.898026
# 213    2024-11-05  222.959290    227.917378     1.436844
# 214    2024-11-06  222.230896    227.115144    -0.728394
# 215    2024-11-07  226.980438    226.806821     4.749542
# 216    2024-11-08  226.710739    226.387714    -0.269699
# 217    2024-11-11  223.983734    225.497343    -2.727005
# 218    2024-11-12  223.983734    224.580032     0.000000
# 219    2024-11-13  224.872757    224.107840     0.889023
# 220    2024-11-14  227.969360    224.363387     3.096603
# 221    2024-11-15  224.752884    224.596628    -3.216476
# 222    2024-11-18  227.769577    225.221341     3.016693
# 223    2024-11-19  228.029282    225.728340     0.259705
# 224    2024-11-20  228.748489    226.380099     0.719208
# 225    2024-11-21  228.269028    226.508958    -0.479462
# 226    2024-11-22  229.617538    226.799638     1.348511
# 227    2024-11-25  232.614243    227.662689     2.996704
# 228    2024-11-26  234.801834    228.744499     2.187592
# 229    2024-11-27  234.671982    229.724422    -0.129852
# 230    2024-11-29  237.069351    230.634421     2.397369
# 231    2024-12-02  239.326859    232.091818     2.257507
# 232    2024-12-03  242.383499    233.553210     3.056641
# 233    2024-12-04  242.743103    235.024593     0.359604
# 234    2024-12-05  242.773071    236.427051     0.029968
# 235    2024-12-06  242.573288    237.857477    -0.199783
# 236    2024-12-09  246.479004    239.543623     3.905716
# 237    2024-12-10  247.497879    241.031987     1.018875
# 238    2024-12-11  246.219284    242.173732    -1.278595
# 239    2024-12-12  247.687683    243.475302     1.468399
# 240    2024-12-13  247.857483    244.554115     0.169800
# 241    2024-12-16  250.764282    245.697858     2.906799
# 242    2024-12-17  253.201599    246.779668     2.437317
# 243    2024-12-18  247.777573    247.283115    -5.424026
# 244    2024-12-19  249.515656    247.957373     1.738083
# 245    2024-12-20  254.210510    249.121095     4.694855
# 246    2024-12-23  254.989655    249.972160     0.779144
# 247    2024-12-24  257.916443    251.014017     2.926788
# 248    2024-12-26  258.735504    252.265639     0.819061
# 249    2024-12-27  255.309296    253.027800    -3.426208
# 250    2024-12-30  251.923019    253.434354    -3.386276
# 251    2024-12-31  250.144974    253.372423    -1.778046
#
# 📊 Stock Data for MSFT:
# Price        Date close_price moving_avg_10 daily_change
# Ticker                   MSFT
# 202    2024-10-21  417.107086    415.532391     0.617554
# 203    2024-10-22  425.802216    416.807278     8.695129
# 204    2024-10-23  422.903839    417.518430    -2.898376
# 205    2024-10-24  423.033295    418.403879     0.129456
# 206    2024-10-25  426.439636    419.582150     3.406342
# 207    2024-10-28  424.885895    420.324176    -1.553741
# 208    2024-10-29  430.224487    421.639902     5.338593
# 209    2024-10-30  430.802155    423.274347     0.577667
# 210    2024-10-31  404.726746    422.241489   -26.075409
# 211    2024-11-01  408.730652    421.465601     4.003906
# 212    2024-11-04  406.828278    420.437720    -1.902374
# 213    2024-11-05  409.816315    418.839130     2.988037
# 214    2024-11-06  418.501465    418.398892     8.685150
# 215    2024-11-07  423.730530    418.468616     5.229065
# 216    2024-11-08  420.852051    417.909857    -2.878479
# 217    2024-11-11  416.340149    417.055283    -4.511902
# 218    2024-11-12  421.340088    416.166843     4.999939
# 219    2024-11-13  423.501465    415.436774     2.161377
# 220    2024-11-14  425.184692    417.482568     1.683228
# 221    2024-11-15  413.342194    417.943723   -11.842499
# 222    2024-11-18  414.099152    418.670810     0.756958
# 223    2024-11-19  416.121063    419.301285     2.021912
# 224    2024-11-20  413.830200    418.834158    -2.290863
# 225    2024-11-21  412.043793    417.665485    -1.786407
# 226    2024-11-22  416.165527    417.196832     4.121735
# 227    2024-11-25  417.951965    417.358014     1.786438
# 228    2024-11-26  427.133545    417.937360     9.181580
# 229    2024-11-27  422.143555    417.801569    -4.989990
# 230    2024-11-29  422.612610    417.544360     0.469055
# 231    2024-12-02  430.117584    419.221899     7.504974
# 232    2024-12-03  430.337128    420.845697     0.219543
# 233    2024-12-04  436.544678    422.888058     6.207550
# 234    2024-12-05  441.734253    425.678464     5.189575
# 235    2024-12-06  442.682373    428.742322     0.948120
# 236    2024-12-09  445.127441    431.638513     2.445068
# 237    2024-12-10  442.442841    434.087601    -2.684601
# 238    2024-12-11  448.091522    436.183398     5.648682
# 239    2024-12-12  448.660370    438.835080     0.568848
# 240    2024-12-13  446.374939    441.211313    -2.285431
# 241    2024-12-16  450.686310    443.268185     4.311371
# 242    2024-12-17  453.550568    445.589529     2.864258
# 243    2024-12-18  436.514740    445.586536   -17.035828
# 244    2024-12-19  436.155457    445.028656    -0.359283
# 245    2024-12-20  435.726318    444.333051    -0.429138
# 246    2024-12-23  434.379028    443.258209    -1.347290
# 247    2024-12-24  438.450836    442.859009     4.071808
# 248    2024-12-26  437.233276    441.773184    -1.217560
# 249    2024-12-27  429.668457    439.873993    -7.564819
# 250    2024-12-30  423.979858    437.634485    -5.688599
# 251    2024-12-31  420.656525    434.631506    -3.323334
#
# 📊 Stock Data for AMZN:
# Price        Date close_price moving_avg_10 daily_change
# Ticker                   AMZN
# 202    2024-10-21  189.070007    187.107001     0.080002
# 203    2024-10-22  189.699997    187.805000     0.629990
# 204    2024-10-23  184.710007    187.759001    -4.989990
# 205    2024-10-24  186.380005    187.732002     1.669998
# 206    2024-10-25  187.830002    187.633002     1.449997
# 207    2024-10-28  188.389999    187.718002     0.559998
# 208    2024-10-29  190.830002    188.032002     2.440002
# 209    2024-10-30  192.729996    188.616002     1.899994
# 210    2024-10-31  186.399994    188.503001    -6.330002
# 211    2024-11-01  197.929993    189.397000    11.529999
# 212    2024-11-04  195.779999    190.067999    -2.149994
# 213    2024-11-05  199.500000    191.048000     3.720001
# 214    2024-11-06  207.089996    193.285999     7.589996
# 215    2024-11-07  210.050003    195.652998     2.960007
# 216    2024-11-08  208.179993    197.687997    -1.870010
# 217    2024-11-11  206.839996    199.532997    -1.339996
# 218    2024-11-12  208.910004    201.340997     2.070007
# 219    2024-11-13  214.100006    203.477998     5.190002
# 220    2024-11-14  211.479996    205.985999    -2.620010
# 221    2024-11-15  202.610001    206.453999    -8.869995
# 222    2024-11-18  201.699997    207.045999    -0.910004
# 223    2024-11-19  204.610001    207.556999     2.910004
# 224    2024-11-20  202.880005    207.136000    -1.729996
# 225    2024-11-21  198.380005    205.969000    -4.500000
# 226    2024-11-22  197.119995    204.863000    -1.260010
# 227    2024-11-25  201.449997    204.324001     4.330002
# 228    2024-11-26  207.860001    204.219000     6.410004
# 229    2024-11-27  205.740005    203.383000    -2.119995
# 230    2024-11-29  207.889999    203.024001     2.149994
# 231    2024-12-02  210.710007    203.834001     2.820007
# 232    2024-12-03  213.440002    205.008002     2.729996
# 233    2024-12-04  218.160004    206.363002     4.720001
# 234    2024-12-05  220.550003    208.130002     2.389999
# 235    2024-12-06  227.029999    210.995001     6.479996
# 236    2024-12-09  226.089996    213.892001    -0.940002
# 237    2024-12-10  225.039993    216.251001    -1.050003
# 238    2024-12-11  230.259995    218.491000     5.220001
# 239    2024-12-12  228.970001    220.814000    -1.289993
# 240    2024-12-13  227.460007    222.771001    -1.509995
# 241    2024-12-16  232.929993    224.992999     5.469986
# 242    2024-12-17  231.149994    226.763998    -1.779999
# 243    2024-12-18  220.520004    226.999998   -10.629990
# 244    2024-12-19  223.289993    227.273997     2.769989
# 245    2024-12-20  224.919998    227.062997     1.630005
# 246    2024-12-23  225.059998    226.959998     0.139999
# 247    2024-12-24  229.050003    227.360999     3.990005
# 248    2024-12-26  227.050003    227.039999    -2.000000
# 249    2024-12-27  223.750000    226.517999    -3.300003
# 250    2024-12-30  221.300003    225.901999    -2.449997
# 251    2024-12-31  219.389999    224.548000    -1.910004
#
# 📊 Stock Data for GOOGL:
# Price        Date close_price moving_avg_10 daily_change
# Ticker                  GOOGL
# 202    2024-10-21  163.693665    163.380376     0.648514
# 203    2024-10-22  164.761200    163.456201     1.067535
# 204    2024-10-23  162.406616    163.547990    -2.354584
# 205    2024-10-24  162.346741    163.611842    -0.059875
# 206    2024-10-25  164.890900    163.814377     2.544159
# 207    2024-10-28  166.337570    163.989972     1.446671
# 208    2024-10-29  169.290787    164.411003     2.953217
# 209    2024-10-30  174.059814    165.338870     4.769028
# 210    2024-10-31  170.717514    166.154996    -3.342300
# 211    2024-11-01  170.897079    166.940189     0.179565
# 212    2024-11-04  168.851807    167.456003    -2.045273
# 213    2024-11-05  169.350647    167.914948     0.498840
# 214    2024-11-06  176.105118    169.284798     6.754471
# 215    2024-11-07  180.335388    171.083662     4.230270
# 216    2024-11-08  177.940903    172.388663    -2.394485
# 217    2024-11-11  179.936310    173.748537     1.995407
# 218    2024-11-12  181.203400    174.939798     1.267090
# 219    2024-11-13  178.469681    175.380785    -2.733719
# 220    2024-11-14  175.177261    175.826759    -3.292419
# 221    2024-11-15  172.094345    175.946486    -3.082916
# 222    2024-11-18  174.897903    176.551096     2.803558
# 223    2024-11-19  177.711411    177.387172     2.813507
# 224    2024-11-20  175.576340    177.334294    -2.135071
# 225    2024-11-21  167.245483    176.025304    -8.330856
# 226    2024-11-22  164.382065    174.669420    -2.863419
# 227    2024-11-25  167.265442    173.402333     2.883377
# 228    2024-11-26  168.732071    172.155200     1.466629
# 229    2024-11-27  168.841812    171.192413     0.109741
# 230    2024-11-29  168.562454    170.530933    -0.279358
# 231    2024-12-02  171.096634    170.431161     2.534180
# 232    2024-12-03  170.946976    170.036069    -0.149658
# 233    2024-12-04  173.970016    169.661929     3.023041
# 234    2024-12-05  172.244003    169.328696    -1.726013
# 235    2024-12-06  174.309265    170.035074     2.065262
# 236    2024-12-09  175.168259    171.113693     0.858994
# 237    2024-12-10  184.956985    172.882848     9.788727
# 238    2024-12-11  195.175217    175.527162    10.218231
# 239    2024-12-12  191.739182    177.816899    -3.436035
# 240    2024-12-13  189.601639    179.920818    -2.137543
# 241    2024-12-16  196.433777    182.454532     6.832138
# 242    2024-12-17  195.195190    184.879353    -1.238586
# 243    2024-12-18  188.183258    186.300677    -7.011932
# 244    2024-12-19  188.293137    187.905591     0.109879
# 245    2024-12-20  191.189804    189.593645     2.896667
# 246    2024-12-23  194.406113    191.517430     3.216309
# 247    2024-12-24  195.884399    192.610172     1.478287
# 248    2024-12-26  195.375000    192.630150    -0.509399
# 249    2024-12-27  192.538254    192.710057    -2.836746
# 250    2024-12-30  191.020004    192.851894    -1.518250
# 251    2024-12-31  189.082245    192.116740    -1.937759
#
# 📊 Stock Data for NVDA:
# Price        Date close_price moving_avg_10 daily_change
# Ticker                   NVDA
# 202    2024-10-21  143.686890    135.896136     5.709091
# 203    2024-10-22  143.566910    136.965965    -0.119980
# 204    2024-10-23  139.537552    137.656856    -4.029358
# 205    2024-10-24  140.387421    138.216768     0.849869
# 206    2024-10-25  141.517227    138.890659     1.129807
# 207    2024-10-28  140.497406    139.135619    -1.019821
# 208    2024-10-29  141.227280    140.100462     0.729874
# 209    2024-10-30  139.317581    140.462404    -1.909698
# 210    2024-10-31  132.738647    140.045471    -6.578934
# 211    2024-11-01  135.378220    139.785513     2.639572
# 212    2024-11-04  136.028122    139.019637     0.649902
# 213    2024-11-05  139.887497    138.651695     3.859375
# 214    2024-11-06  145.586578    139.256598     5.699081
# 215    2024-11-07  148.856064    140.103462     3.269485
# 216    2024-11-08  147.606247    140.712364    -1.249817
# 217    2024-11-11  145.236618    141.186285    -2.369629
# 218    2024-11-12  148.266129    141.890170     3.029510
# 219    2024-11-13  146.246475    142.583060    -2.019653
# 220    2024-11-14  146.736374    143.982832     0.489899
# 221    2024-11-15  141.957153    144.640726    -4.779221
# 222    2024-11-18  140.127441    145.050658    -1.829712
# 223    2024-11-19  146.986343    145.760542     6.858902
# 224    2024-11-20  145.866531    145.788538    -1.119812
# 225    2024-11-21  146.646408    145.567572     0.779877
# 226    2024-11-22  141.927155    144.999663    -4.719254
# 227    2024-11-25  135.998123    144.075813    -5.929031
# 228    2024-11-26  136.897980    142.938998     0.899857
# 229    2024-11-27  135.318222    141.846173    -1.579758
# 230    2024-11-29  138.227768    140.995313     2.909546
# 231    2024-12-02  138.607697    140.660367     0.379929
# 232    2024-12-03  140.237442    140.671367     1.629745
# 233    2024-12-04  145.116653    140.484398     4.879211
# 234    2024-12-05  145.046661    140.402411    -0.069992
# 235    2024-12-06  142.426895    139.980460    -2.619766
# 236    2024-12-09  138.797226    139.667467    -3.629669
# 237    2024-12-10  135.057587    139.573413    -3.739639
# 238    2024-12-11  139.297180    139.813333     4.239594
# 239    2024-12-12  137.327362    140.014247    -1.969818
# 240    2024-12-13  134.237656    139.615236    -3.089706
# 241    2024-12-16  131.987854    138.953252    -2.249802
# 242    2024-12-17  130.378006    137.967308    -1.609848
# 243    2024-12-18  128.898148    136.345457    -1.479858
# 244    2024-12-19  130.667969    134.907588     1.769821
# 245    2024-12-20  134.687607    134.133659     4.019638
# 246    2024-12-23  139.657150    134.219652     4.969543
# 247    2024-12-24  140.207108    134.734604     0.549957
# 248    2024-12-26  139.917130    134.796599    -0.289978
# 249    2024-12-27  136.997391    134.763602    -2.919739
# 250    2024-12-30  137.477356    135.087572     0.479965
# 251    2024-12-31  134.277649    135.316551    -3.199707
# Real-time data fetched for AAPL from Yahoo Finance
# Real-time data updated for AAPL in PostgreSQL
# Real-time data fetched for MSFT from Yahoo Finance
# Real-time data updated for MSFT in PostgreSQL
# Real-time data fetched for AMZN from Yahoo Finance
# Real-time data updated for AMZN in PostgreSQL
# Real-time data fetched for GOOGL from Yahoo Finance
# Real-time data updated for GOOGL in PostgreSQL
# Real-time data fetched for NVDA from Yahoo Finance
# Real-time data updated for NVDA in PostgreSQL
